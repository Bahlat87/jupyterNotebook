# %% [markdown]
# ## Bundesliga German Football Table Web Scraping

# %%
# Import libraries

import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.bundesliga.com/en/bundesliga/table"

response = requests.get(url)

response.status_code
# Out:
# 200

# %% [markdown]
# ## Get Soup

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/><meta charset="utf-8"/><title>Bundesliga | Table | 2021-2022</title><script type="text/javascript">let shouldUseDarkTheme="0";const availibleThemes=["light","dark"];localStorage&&availibleThemes.includes(localStorage.getItem("bl-force-theme"))?shouldUseDarkTheme="dark"===localStorage.getItem("bl-force-theme")?"1":"0":window.matchMedia&&window.matchMedia("(prefers-color-scheme:dark)").matches&&(shouldUseDarkTheme="1"),window.document.documentElement.setAttribute("dark",shouldUseDarkTheme)</script><base href="/"/><link href="assets/favicons/favicon.ico" rel="shortcut icon" type="image/x-icon"/><link href="assets/favicons/favicon-16x16.png" rel="icon" sizes="16x16"/><link href="assets/favicons/favicon-32x32.png" rel="icon" sizes="32x32"/><link href="assets/favicons/android-chrome-192x192.png" rel="icon" sizes="192x192"/><link href="assets/favicons/apple-touch-icon-180x180.png" rel="icon" sizes="180x180"/><link href="assets/favicons/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/><link href="assets/favicons/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/><link color="#c80a00" href="assets/favicons/safari-pinned-tab_new.svg" rel="mask-icon"/><link as="font" crossorigin="crossorigin" href="/assets/fonts/DFLWeb-Rg.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="crossorigin" href="/assets/fonts/DFLWeb-Bd.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="crossorigin" href="/assets/fonts/DFLWeb-Lt.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="crossorigin" href="/assets/fonts/DFLWeb-It.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="crossorigin" href="/assets/fonts/DFLCnWeb-Rg.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="crossorigin" href="/assets/fonts/DFLCnWeb-Bd.woff2" rel="preload" type="font/woff2"/><style type="text/css">@font-face{font-family:'Material Icons';font-style:normal;font-weight:400;src:url(https://fonts.gstatic.com/s/materialicons/v121/flUhRq6tzZclQEJ-Vdg-IuiaDsNcIhQ8tQ.woff2) format('woff2');}.material-icons{font-family:'Material Icons';font-weight:normal;font-style:normal;font-size:24px;line-height:1;letter-spacing:normal;text-transform:none;display:inline-block;white-space:nowrap;word-wrap:normal;direction:ltr;-webkit-font-feature-settings:'liga';-webkit-font-smoothing:antialiased;}</style><meta content="Bundesliga" name="apple-mobile-web-app-title"/><meta content="#c80a00" name="msapplication-TileColor"/><meta content="assets/favicons/mstile-144x144.png" name="msapplication-TileImage"/><meta content="width=device-width,initial-scale=1" name="viewport"/><meta content="dark light" name="color-scheme"/><script nomodule="" src="polyfills.legacy.min.js"></script><link crossorigin="use-credentials" href="styles.23ec017b19ae4336.css" rel="stylesheet"/><style ng-transition="my-app"></style><link href="https://www.googletagservices.com" rel="preconnect"/><link href="https://www.googletagmanager.com" rel="preconnect"/><link href="https://w.usabilla.com" rel="preconnect"/><script id="sls--gtag" type="text/javascript">!function(e,t,a,n){e[n]=e[n]||[],e[n].push({"gtm.start":(new Date).getTime(),event:"gtm.js"});n=t.getElementsByTagName(a)[0],a=t.createElement(a);a.async=!0,a.src="//www.googletagmanager.com/gtm.js?id=GTM-NLQHQQ",n.parentNode.insertBefore(a,n)}(window,document,"script","dataLayer")</script><style ng-transition="my-app">.container-fluid.wrapper[_ngcontent-sc103]{position:relative;padding-bottom:50px}.container-fluid.wrapper[_ngcontent-sc103]   .loader[_ngcontent-sc103]{position:absolute;top:0;left:0;right:0;bottom:0;display:block;width:100%;height:100%;background-color:#0009;z-index:5}.container-fluid.wrapper[_ngcontent-sc103]   .loader[_ngcontent-sc103]   dfl-loader-modern[_ngcontent-sc103]{position:fixed;top:50%;left:50%;transform:translate(-50%)}</style><style ng-transit ...

# %%
results = soup.find('table', {'class': 'table'}).find_all('tr')

# %%
results
# Out:
# [<tr _ngcontent-sc235=""><th _ngcontent-sc235="" class="qual" scope="col"></th><th _ngcontent-sc235="" class="rank"></th><th _ngcontent-sc235="" class="tend"></th><th _ngcontent-sc235="" class="logo"></th><th _ngcontent-sc235="" class="team"></th><th _ngcontent-sc235="" class="live"></th><th _ngcontent-sc235="" class="matches"><span _ngcontent-sc235="" class="d-none d-lg-inline">Played </span><span _ngcontent-sc235="" class="d-lg-none">P</span></th><th _ngcontent-sc235="" class="pts"><span _ngcontent-sc235="" class="d-none d-lg-inline">Points </span><span _ngcontent-sc235="" class="d-lg-none">Pts</span></th><th _ngcontent-sc235="" class="d-none d-lg-table-cell wins">W</th><th _ngcontent-sc235="" class="d-none d-lg-table-cell draws">D</th><th _ngcontent-sc235="" class="d-none d-lg-table-cell looses">L</th><th _ngcontent-sc235="" class="d-none d-md-table-cell goals"><span _ngcontent-sc235="" class="d-none d-md-inline">Goals </span><span _ngcontent-sc235="" class="d-md-none">G</span></th><th _ngcontent-sc235="" class="difference">Goal difference</th></tr>,
#  <tr _ngcontent-sc235="" class="table-DFL-CLU-00000G ng-star-inserted"><td _ngcontent-sc235="" class="UEFA_CHAMPIONS_LEAGUE qual" scope="col" style="background:#138F16;"><div _ngcontent-sc235=""></div></td><td _ngcontent-sc235="" class="rank">1</td><td _ngcontent-sc235="" class="tend"><span _ngcontent-sc235="" class="stable" title="Form">-</span></td><td _ngcontent-sc235="" class="logo"><a _ngcontent-sc235="" class="logolink" href="/en/bundesliga/clubs/fc-bayern-muenchen" title="FC Bayern München"><clublogo _ngcontent-sc235="" _nghost-sc127=""><img _ngcontent-sc127="" alt="FC Bayern München" class="logo ng-star-inser
#  <tr _ngcontent-sc235="" class="table-DFL-CLU-00000D ng-star-inserted"><td _ngcontent-sc235="" class="RELEGATION qual" scope="col" style="background:#D75452;"><div _ngcontent-sc235=""></div></td><td _ngcontent-sc235="" class="rank">17</td><td _ngcontent-sc235="" class="tend"><span _ngcontent-sc235="" class="stable" title="Form">-</span></td><td _ngcontent-sc235="" class="logo"><a _ngcontent-sc235="" class="logolink" href="/en/bundesliga/clubs/vfb-stuttgart" title="VfB Stuttgart"><clublogo _ngcontent-sc235="" _nghost-sc127=""><img _ngcontent-sc127="" alt="VfB Stuttgart" class="logo ng-star-inserted" src="/assets/clublogo/default_clublogo.svg"/></clublogo></a></td><td _ngcontent-sc235="" class="team"><a _ngcontent-sc235="" href="/en/bundesliga/clubs/vfb-stuttgart" title="VfB Stuttgart"><span _ngcontent-sc235="" class="d-inline d-sm-none">VFB </span><span _ngcontent-sc235="" class="d-none d-sm-inline d-lg-none">Stuttgart </span><span _ngcontent-sc235="" class="d-none d-lg-inline">VfB Stuttgart</span></a></td><td _ngcontent-sc235="" class="live"></td><td _ngcontent-sc235="" class="matches">20</td><td _ngcontent-sc235="" class="pts">18</td><td _ngcontent-sc235="" class="d-none d-lg-table-cell wins">4</td><td _ngcontent-sc235="" class="d-none d-lg-table-cell draws">6</td><td _ngcontent-sc235="" class="d-none d-lg-table-cell looses">10</td><td _ngcontent-sc235="" class="d-none d-md-table-cell goals">22:35</td><td _ngcontent-sc235="" class="difference">-13</td></tr>,
#  <tr _ngcontent-sc235="" class="table-DFL-CLU-00000W ng-star-inserted"><td _ngcontent-sc235="" class="RELEGATION qual" scope="col" style="background:#D75452;"><div _ngcontent-sc235=""></div></td><td _ngcontent-sc235="" class="rank">18</td><td _ngcontent-sc235="" class="tend"><span _ngcontent-sc235="" class="stable" title="Form">-</span></td><td _ngcontent-sc235="" class="logo"><a _ngcontent-sc235="" class="logolink" href="/en/bundesliga/clubs/spvgg-greuther-fuerth" title="SpVgg Greuther Fürth"><clublogo _ngcontent-sc235="" _nghost-sc127=""><img _ngcontent-sc127="" alt="SpVgg Greuther Fürth" class="logo ng-star-inserted" src="/assets/clublogo/default_clublogo.svg"/></clublogo></a></td><td _ngcontent-sc235="" class="team"><a _ngcontent-sc235="" href="/en/bundesliga/clubs/spvgg-greuther-fuerth" title="SpVgg Greuther Fürth"><span _ngcontent-sc235="" class="d-inline d-sm-none">SGF </span><span _ngcontent-sc235="" class="d-none d-sm-inline d-lg-none">Fürth </span><span _ngcontent-sc235="" class="d-none d-lg-inline">SpVgg Greuther Fürth</span></a></td><td _ngcontent-sc235="" class="live"></td><td _ngcontent-sc235="" class="matches">20</td><td _ngcontent-sc235="" class="pts">10</td><td _ngcontent-sc235="" class="d-none d-lg-table-cell wins">2</td><td _ngcontent-sc235="" class="d-none d-lg-table-cell draws">4</td><td _ngcontent-sc235="" class="d-none d-lg-table-cell looses">14</td><td _ngcontent-sc235="" class="d-none d-md-table-cell goals">17:52</td><td _ngcontent-sc235="" class="difference">-35</td></tr>]

# %%
# Remove first row:

results = results[1:]

# %% [markdown]
# ## Get Team Name

# %%
results[0].find('td', {'class': 'team'}).find('span', {'class': 'd-none d-lg-inline'}).get_text()
# Out:
# 'FC Bayern München'

# %%
results[17].find('td', {'class': 'team'}).find('span', {'class': 'd-none d-lg-inline'}).get_text()
# Out:
# 'SpVgg Greuther Fürth'

# %% [markdown]
# ## Number Of Matches

# %%
results[0].find('td', {'class': 'matches'}).get_text()
# Out:
# '20'

# %% [markdown]
# ## Points

# %%
results[0].find('td', {'class': 'pts'}).get_text()
# Out:
# '49'

# %% [markdown]
# ## Wins, Draws, Losses

# %%
# Wins:

results[0].find('td', {'class': 'd-none d-lg-table-cell wins'}).get_text()
# Out:
# '16'

# %%
# Draws:

results[0].find('td', {'class': 'd-none d-lg-table-cell draws'}).get_text()
# Out:
# '1'

# %%
# Losses

results[0].find('td', {'class': 'd-none d-lg-table-cell looses'}).get_text()
# Out:
# '3'

# %% [markdown]
# ## Goals

# %%
results[0].find('td', {'class': 'd-none d-md-table-cell goals'}).get_text()
# Out:
# '65:19'

# %% [markdown]
# ## Goal Difference

# %%
# Remove plus sign cases

results[0].find('td', {'class': 'difference'}).get_text().replace("+", "")
# Out:
# '46'

# %%
results[17].find('td', {'class': 'difference'}).get_text().replace("+", "")
# Out:
# '-35'

# %% [markdown]
# ## Creating Table

# %%
# Webscrape the table, I use list comprhension instead of for loop append method:

teams = [result.find('td', {'class': 'team'}).find('span', {'class': 'd-none d-lg-inline'}).get_text() 
         for result in results]
    
matches = [result.find('td', {'class': 'matches'}).get_text() for result in results]

points = [result.find('td', {'class': 'pts'}).get_text() for result in results]

wins = [result.find('td', {'class': 'd-none d-lg-table-cell wins'}).get_text() for result in results]

draws = [result.find('td', {'class': 'd-none d-lg-table-cell draws'}).get_text() for result in results]

losses = [result.find('td', {'class': 'd-none d-lg-table-cell looses'}).get_text() for result in results]

goals = [result.find('td', {'class': 'd-none d-md-table-cell goals'}).get_text() for result in results]

goal_diff = [result.find('td', {'class': 'difference'}).get_text().replace("+", "") for result in results]

# %%
## Make pandas Dataframe:

bundesliga_df = pd.DataFrame({'Rank': range(1, 19), 'Team': teams, 'Matches': matches,
                              'Points': points, 'Wins': wins, 'Draws': draws,
                              'Losses': losses, 'Goals': goals, 'Goal Difference': goal_diff})

# %%
bundesliga_df
# Out:
#     Rank                  Team Matches Points Wins Draws Losses  Goals  \
# 0      1     FC Bayern München      20     49   16     1      3  65:19
# 1      2     Borussia Dortmund      20     43   14     1      5  52:31
# 2      3   Bayer 04 Leverkusen      20     35   10     5      5  49:32
# 3      4    1. FC Union Berlin      20     34    9     7      4  29:25
# 4      5           SC Freiburg      20     33    9     6      5  33:23
# 5      6            RB Leipzig      20     31    9     4      7  38:23
# 6      7        TSG Hoffenheim      20     31    9     4      7  41:32
# 7      8            1. FC Köln      20     29    7     8      5  32:34
# 8      9   Eintracht Frankfurt      20     28    7     7      6  30:30
# 9     10       1. FSV Mainz 05      20     27    8     3      9  28:23
# 10    11       VfL Bochum 1848      20     24    7     3     10  19:29
# 11    12   Borussia M'gladbach      20     22    6     4     10  26:37
# 12    13         Hertha Berlin      20     22    6     4     10  22:42
# 13    14     Arminia Bielefeld      20     21    4     9      7  20:26
# 14    15         VfL Wolfsburg      20     21    6     3     11  17:32
# 15    16           FC Augsburg      20     19    4     7      9  20:35
# 16    17         VfB Stuttgart      20     18    4     6     10  22:35
# 17    18  SpVgg Greuther Fürth      20     10    2     4     14  17:52
#
#    Goal Difference
# 0               46
# 1               21
# 2               17
# 3                4
# 4               10
# 5               15
# 6                9
# 7               -2
# 8                0
# 9                5
# 10             -10
# 11             -11
# 12             -20
# 13              -6
# 14             -15
# 15             -15
# 16             -13
# 17             -35

# %%
## Split Goals Into Goals For & Goals Against:

bundesliga_df[['Goals For','Goals Against']] = bundesliga_df['Goals'].str.split(":",expand=True,)

# %%
bundesliga_df
# Out:
#     Rank                  Team Matches Points Wins Draws Losses  Goals  \
# 0      1     FC Bayern München      20     49   16     1      3  65:19
# 1      2     Borussia Dortmund      20     43   14     1      5  52:31
# 2      3   Bayer 04 Leverkusen      20     35   10     5      5  49:32
# 3      4    1. FC Union Berlin      20     34    9     7      4  29:25
# 4      5           SC Freiburg      20     33    9     6      5  33:23
# 5      6            RB Leipzig      20     31    9     4      7  38:23
# 6      7        TSG Hoffenheim      20     31    9     4      7  41:32
# 7      8            1. FC Köln      20     29    7     8      5  32:34
# 8      9   Eintracht Frankfurt      20     28    7     7      6  30:30
# 9     10       1. FSV Mainz 05      20     27    8     3      9  28:23
# 10    11       VfL Bochum 1848      20     24    7     3     10  19:29
# 11    12   Borussia M'gladbach      20     22    6     4     10  26:37
# 12    13         Hertha Berlin      20     22    6     4     10  22:42
# 13    14     Arminia Bielefeld      20     21    4     9      7  20:26
# 14    15         VfL Wolfsburg      20     21    6     3     11  17:32
# 15    16           FC Augsburg      20     19    4     7      9  20:35
# 16    17         VfB Stuttgart      20     18    4     6     10  22:35
# 17    18  SpVgg Greuther Fürth      20     10    2     4     14  17:52
#
#    Goal Difference Goals For Goals Against
# 0               46        65            19
# 1               21        52            31
# 2               17        49            32
# 3                4        29            25
# 4               10        33            23
# 5               15        38            23
# 6                9        41            32
# 7               -2        32            34
# 8                0        30            30
# 9                5        28            23
# 10             -10        19            29
# 11             -11        26            37
# 12             -20        22            42
# 13              -6        20            26
# 14             -15        17            32
# 15             -15        20            35
# 16             -13        22            35
# 17             -35        17            52

# %%
# Drop Goals column and rearrange columns:

bundesliga_df.drop('Goals', axis = 1, inplace = True)

bundesliga_df
# Out:
#     Rank                  Team Matches Points Wins Draws Losses  \
# 0      1     FC Bayern München      20     49   16     1      3
# 1      2     Borussia Dortmund      20     43   14     1      5
# 2      3   Bayer 04 Leverkusen      20     35   10     5      5
# 3      4    1. FC Union Berlin      20     34    9     7      4
# 4      5           SC Freiburg      20     33    9     6      5
# 5      6            RB Leipzig      20     31    9     4      7
# 6      7        TSG Hoffenheim      20     31    9     4      7
# 7      8            1. FC Köln      20     29    7     8      5
# 8      9   Eintracht Frankfurt      20     28    7     7      6
# 9     10       1. FSV Mainz 05      20     27    8     3      9
# 10    11       VfL Bochum 1848      20     24    7     3     10
# 11    12   Borussia M'gladbach      20     22    6     4     10
# 12    13         Hertha Berlin      20     22    6     4     10
# 13    14     Arminia Bielefeld      20     21    4     9      7
# 14    15         VfL Wolfsburg      20     21    6     3     11
# 15    16           FC Augsburg      20     19    4     7      9
# 16    17         VfB Stuttgart      20     18    4     6     10
# 17    18  SpVgg Greuther Fürth      20     10    2     4     14
#
#    Goal Difference Goals For Goals Against
# 0               46        65            19
# 1               21        52            31
# 2               17        49            32
# 3                4        29            25
# 4               10        33            23
# 5               15        38            23
# 6                9        41            32
# 7               -2        32            34
# 8                0        30            30
# 9                5        28            23
# 10             -10        19            29
# 11             -11        26            37
# 12             -20        22            42
# 13              -6        20            26
# 14             -15        17            32
# 15             -15        20            35
# 16             -13        22            35
# 17             -35        17            52

# %%
bundesliga_df = bundesliga_df.reindex(columns=['Rank', 'Team', 'Matches', 'Points',
                                               'Wins', 'Draws', 'Losses', 'Goals For',
                                               'Goals Against', 'Goal Difference'])

# %%
bundesliga_df
# Out:
#     Rank                  Team Matches Points Wins Draws Losses Goals For  \
# 0      1     FC Bayern München      20     49   16     1      3        65
# 1      2     Borussia Dortmund      20     43   14     1      5        52
# 2      3   Bayer 04 Leverkusen      20     35   10     5      5        49
# 3      4    1. FC Union Berlin      20     34    9     7      4        29
# 4      5           SC Freiburg      20     33    9     6      5        33
# 5      6            RB Leipzig      20     31    9     4      7        38
# 6      7        TSG Hoffenheim      20     31    9     4      7        41
# 7      8            1. FC Köln      20     29    7     8      5        32
# 8      9   Eintracht Frankfurt      20     28    7     7      6        30
# 9     10       1. FSV Mainz 05      20     27    8     3      9        28
# 10    11       VfL Bochum 1848      20     24    7     3     10        19
# 11    12   Borussia M'gladbach      20     22    6     4     10        26
# 12    13         Hertha Berlin      20     22    6     4     10        22
# 13    14     Arminia Bielefeld      20     21    4     9      7        20
# 14    15         VfL Wolfsburg      20     21    6     3     11        17
# 15    16           FC Augsburg      20     19    4     7      9        20
# 16    17         VfB Stuttgart      20     18    4     6     10        22
# 17    18  SpVgg Greuther Fürth      20     10    2     4     14        17
#
#    Goals Against Goal Difference
# 0             19              46
# 1             31              21
# 2             32              17
# 3             25               4
# 4             23              10
# 5             23              15
# 6             32               9
# 7             34              -2
# 8             30               0
# 9             23               5
# 10            29             -10
# 11            37             -11
# 12            42             -20
# 13            26              -6
# 14            32             -15
# 15            35             -15
# 16            35             -13
# 17            52             -35

# %% [markdown]
# ## All In One Function
#
# Putting it all together in one function. I did not include saving the table into a .csv or Excel file. All the values are strings. The user would have to convert them into numeric if they want to.

# %%
def bundesliga_scrape():
    
    url = "https://www.bundesliga.com/en/bundesliga/table"

    response = requests.get(url)
    
    soup = BeautifulSoup(response.content, 'html.parser')
    
    results = soup.find('table', {'class': 'table'}).find_all('tr')
    
    # Remove first row:

    results = results[1:]
    
    # Webscrape the table, I use list comprhension instead of for loop append method:

    teams = [result.find('td', {'class': 'team'}).find('span', {'class': 'd-none d-lg-inline'}).get_text() 
             for result in results]  
    matches = [result.find('td', {'class': 'matches'}).get_text() for result in results]
    points = [result.find('td', {'class': 'pts'}).get_text() for result in results]

    wins = [result.find('td', {'class': 'd-none d-lg-table-cell wins'}).get_text() for result in results]
    draws = [result.find('td', {'class': 'd-none d-lg-table-cell draws'}).get_text() for result in results]
    losses = [result.find('td', {'class': 'd-none d-lg-table-cell looses'}).get_text() for result in results]

    goals = [result.find('td', {'class': 'd-none d-md-table-cell goals'}).get_text() for result in results]
    goal_diff = [result.find('td', {'class': 'difference'}).get_text().replace("+", "") for result in results]
    
    ## Make pandas Dataframe:

    df = pd.DataFrame({'Rank': range(1, 19), 'Team': teams, 'Matches': matches,
                              'Points': points, 'Wins': wins, 'Draws': draws,
                              'Losses': losses, 'Goals': goals, 'Goal Difference': goal_diff})
    
    # Split Goals Into Goals For & Goals Against:
    df[['Goals For','Goals Against']] = df['Goals'].str.split(":",expand=True,)
    
    # Drop Goals column
    df.drop('Goals', axis = 1, inplace = True)
    
    # Rearrange columns
    df = df.reindex(columns=['Rank', 'Team', 'Matches', 'Points',
                             'Wins', 'Draws', 'Losses', 'Goals For',
                             'Goals Against', 'Goal Difference'])
    return df

# %%
# Function Call

bundesliga_df = bundesliga_scrape()

bundesliga_df
# Out:
#     Rank                  Team Matches Points Wins Draws Losses Goals For  \
# 0      1     FC Bayern München      20     49   16     1      3        65
# 1      2     Borussia Dortmund      20     43   14     1      5        52
# 2      3   Bayer 04 Leverkusen      20     35   10     5      5        49
# 3      4    1. FC Union Berlin      20     34    9     7      4        29
# 4      5           SC Freiburg      20     33    9     6      5        33
# 5      6            RB Leipzig      20     31    9     4      7        38
# 6      7        TSG Hoffenheim      20     31    9     4      7        41
# 7      8            1. FC Köln      20     29    7     8      5        32
# 8      9   Eintracht Frankfurt      20     28    7     7      6        30
# 9     10       1. FSV Mainz 05      20     27    8     3      9        28
# 10    11       VfL Bochum 1848      20     24    7     3     10        19
# 11    12   Borussia M'gladbach      20     22    6     4     10        26
# 12    13         Hertha Berlin      20     22    6     4     10        22
# 13    14     Arminia Bielefeld      20     21    4     9      7        20
# 14    15         VfL Wolfsburg      20     21    6     3     11        17
# 15    16           FC Augsburg      20     19    4     7      9        20
# 16    17         VfB Stuttgart      20     18    4     6     10        22
# 17    18  SpVgg Greuther Fürth      20     10    2     4     14        17
#
#    Goals Against Goal Difference
# 0             19              46
# 1             31              21
# 2             32              17
# 3             25               4
# 4             23              10
# 5             23              15
# 6             32               9
# 7             34              -2
# 8             30               0
# 9             23               5
# 10            29             -10
# 11            37             -11
# 12            42             -20
# 13            26              -6
# 14            32             -15
# 15            35             -15
# 16            35             -13
# 17            52             -35

# %%
# Today's date:

from datetime import date

date.today()
# Out:
# 2022-01-27

# %%
'bundesliga_table_' + str(date.today())
# Out:
# 'bundesliga_table_2022-01-27'

# %%
# Save to .csv:

bundesliga_df.to_csv('bundesliga_table_' + str(date.today()) + '.csv', index = False)
